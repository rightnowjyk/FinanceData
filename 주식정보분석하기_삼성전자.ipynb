# %%
# !pip install finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in c:\users\jukim\anaconda3\lib\site-packages (0.9.50)
# Requirement already satisfied: requests-file in c:\users\jukim\anaconda3\lib\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\jukim\anaconda3\lib\site-packages (from finance-datareader) (1.4.4)
# Requirement already satisfied: tqdm in c:\users\jukim\anaconda3\lib\site-packages (from finance-datareader) (4.64.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\jukim\anaconda3\lib\site-packages (from finance-datareader) (2.28.1)
# Requirement already satisfied: lxml in c:\users\jukim\anaconda3\lib\site-packages (from finance-datareader) (4.9.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\jukim\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jukim\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jukim\anaconda3\lib\site-packages (from pandas>=0.19.2->finance-datareader) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jukim\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\jukim\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jukim\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jukim\anaconda3\lib\site-packages (from requests>=2.3.0->finance-datareader) (1.26.11)
# Requirement already satisfied: six in c:\users\jukim\anaconda3\lib\site-packages (from requests-file->finance-datareader) (1.16.0)
# Requirement already satisfied: colorama in c:\users\jukim\anaconda3\lib\site-packages (from tqdm->finance-datareader) (0.4.5)

# %%
import FinanceDataReader as fdr
df_krx = fdr.StockListing('KRX')
df_krx
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          61800          1
# 1     373220  KR7373220003  LG에너지솔루션  KOSPI         522000          1
# 2     000660  KR7000660001    SK하이닉스  KOSPI          91400          1
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         804000          1
# 4     006400  KR7006400006     삼성SDI  KOSPI         720000          1
# ...      ...           ...       ...    ...    ...     ...        ...
# 2692  308700  KR7308700004       테크엔  KONEX  일반기업부     599          1
# 2693  215050  KR7215050006   비엔디생활건강  KONEX  일반기업부     912          0
# 2694  267810  KR7267810000        앙츠  KONEX  일반기업부     951          2
# 2695  267060  KR7267060002     명진홀딩스  KONEX  일반기업부     181          0
# 2696  322190  KR7322190000        베른  KONEX  일반기업부     103          2
#
#       Changes  ChagesRatio    Open    High     Low    Volume         Amount  \
# 0         800         1.31   62600   62700   61000  18570133  1145781815984
# 1        1000         0.19  527000  531000  518000    428384   224408197000
# 2        2900         3.28   91200   91400   88500   3889171   350718422181
# 3       11000         1.39  793000  805000  788000     75059    59925602000
# 4       35000         5.11  697000  721000  691000    397659   283587815000
# ...       ...          ...     ...     ...     ...       ...            ...
# 2692       39         6.96     560     599     560         3           1719
# 2693        0         0.00       0       0       0         0              0
# 2694      -90        -8.65    1041    1041     902       131         122598
# 2695        0         0.00       0       0       0         0              0
# 2696       -3        -2.83     117     117      98       386          40087
#
#                Marcap      Stocks MarketId
# 0     368932561590000  5969782550      STK
# 1     122148000000000   234000000      STK
# 2      66539416161000   728002365      STK
# 3      57223896000000    71174000      STK
# 4      49510461600000    68764530      STK
# ...               ...         ...      ...
# 2692       2396000000     4000000      KNX
# 2693       1934959392     2121666      KNX
# 2694       1699437000     1787000      KNX
# 2695       1654666524     9141804      KNX
# 2696        919295291     8925197      KNX
#
# [2697 rows x 17 columns]

# %%
df = fdr.DataReader('005930', '2022')
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-01-03  79400  79800  78200  78600  13502112  0.003831
# 2022-01-04  78800  79200  78300  78700  12427416  0.001272
# 2022-01-05  78800  79000  76400  77400  25470640 -0.016518
# 2022-01-06  76700  77600  76600  76900  12931954 -0.006460
# 2022-01-07  78100  78400  77400  78300  15163757  0.018205
# ...           ...    ...    ...    ...       ...       ...
# 2023-01-26  63800  63900  63300  63900  13278277  0.007886
# 2023-01-27  64400  65000  63900  64600  18760182  0.010955
# 2023-01-30  64900  64900  63100  63300  20995234 -0.020124
# 2023-01-31  63500  63700  61000  61000  29746731 -0.036335
# 2023-02-01  62600  62700  61000  61800  17148172  0.013115
#
# [267 rows x 6 columns]

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
